# %% [markdown]
# Сценарий Foursquare
#
# Напишите сценарий на языке Python, который предложит пользователю ввести интересующую его категорию (например, кофейни, музеи, парки и т.д.).
#
# Используйте API Foursquare для поиска заведений в указанной категории.
#
# Получите название заведения, его адрес и рейтинг для каждого из них.
#
# Скрипт должен вывести название и адрес и рейтинг каждого заведения в консоль.

# %%
import os
import requests
from dotenv import load_dotenv
from fake_useragent import UserAgent
from pprint import pprint

# %%
ua = UserAgent()

# %%
category = input("Введите название интересующей Вас категории на английском языке (например: Park, Zoos, Museums и т.п.) : ")

# %%
url = "https://api.foursquare.com/v3/places/search"

# %%
params = {
    'limit': 50,
    'query': category,
    'fields': 'name,location,rating'
}

# %%
headers = {
    "User-Agent": ua.firefox,
    "Accept": "application/json",
    "Authorization": "fsq3P6zWw5hrHAp69JoTu+0TFeYEBCEXDIo7+Ivypcz/4Uo="
}

# %%
response = requests.request("GET", url, params=params, headers=headers)

# %%
if response.status_code == 200:
    print("Успешный запрос API по URL: ", response.url)
else:
    print("Запрос API отклонен с кодом состояния:", response.status_code)
# Out:
# Успешный запрос API по URL:  https://api.foursquare.com/v3/places/search?limit=50&query=&fields=name%2Clocation%2Crating

# %%
data = response.json()
pprint(data)
# Out:
# {'context': {'geo_bounds': {'circle': {'center': {'latitude': 55.7524,
#                                                   'longitude': 49.1388},
#                                        'radius': 22000}}},
#  'results': [{'location': {'address': 'островского 57',
#                            'country': 'RU',
#                            'cross_street': '',
#                            'formatted_address': 'островского 57, Казань',
#                            'locality': 'Казань',
#                            'region': 'Татарстан'},
#               'name': 'Контора 57',
#               'rating': 8.9},
#              {'location': {'address': 'Декабристов Ул., д. 1',
#                            'country': 'RU',
#                            'cross_street': '',
#                            'formatted_address': 'Декабристов Ул., д. 1, '
#                                                 '420107, Казань',
#                            'locality': 'Казань',
#                            'postcode': '420107',
#                            'region': 'Татарстан'},
#               'name': 'Золотое яблоко',
#               'rating': 8.9},
#              {'location': {'address': 'Университетская Ул., д. 6',
#                            'country': 'RU',
#                            'cross_street': 'Университетская ул., 6',
#                            'formatted_address': 'Университетская Ул., д. 6 '
#                                                 '(Университетская ул., 6), '
#                                                 '420111, Казань',
#                            'locality': 'Казань',
#                            'postcode': '420111',
#                            'region': 'Татарстан'},
#               'name': 'Музей социалистического быта',
#               'rating': 8.9},
#              {'location': {'address': 'Петербургская, 9',
#                            'country': 'RU',
#                            'cross_street': '',
#                            'formatted_address': 'Петербургская, 9, 420107, '
#                                                 'Казань',
#                            'locality': 'Казань',
#                            'postcode': '420107',
#                            'region': 'Татарстан'},
#               'name': 'Галерея Славы Зайцева',
#               'rating': 9.1},
#              {'location': {'address': 'Астрономическая/Профсоюзная Ул., '
#                                       'д.15/19',
#                            'country': 'RU',
#                            'cross_street': '',
#                            'formatted_address': 'Астрономическая/Профсоюзная '
#                                                 'Ул., д.15/19, 420111, Казань',
#                            'locality': 'Казань',
#                            'postcode': '420111',
#                            'region': 'Республика Татарстан'},
#               'name': 'АВА-Казань',
#               'rating': 8.8},
#              {'location': {'address': 'Мусы Джалиля Ул., д. 21',
#                            'country': 'RU',
#                            'cross_street': 'ул. Рахматуллина',
#                            'formatted_address': 'Мусы Джалиля Ул., д. 21 (ул. '
#                                                 'Рахматуллина), 420111, Казань',
#                            'locality': 'Казань',
#                            'postcode': '420111',
#                            'region': 'Татарстан'},
#               'name': 'Петропавловский собор',
#               'rating': 9.3},
#              {'location': {'country': 'RU',
#                            'formatted_address': 'Казань',
#                            'locality': 'Казань',
#                            'region': 'Татарстан'},
#               'name': 'ЦПКиО им. Горького',
#               'rating': 9.2},
#              {'location': {'address': 'Ул. Баумана, 9',
#                            'country': 'RU',
#                            'cross_street': '',
#                            'formatted_address': 'Ул. Баумана, 9, 420000, '
#                                                 'Казань',
#                            'locality': 'Казань',
#                            'postcode': '420000',
#                            'region': 'Татарстан'},
#               'name': 'Штофъ',
#               'rating': 8.8},
#              {'location': {'address': 'Профсоюзная Ул., д. 10/14',
#                            'country': 'RU',
#                            'cross_street': '',
#                            'formatted_address': 'Профсоюзная Ул., д. 10/14, '
#                                                 'Казань',
#                            'locality': 'Казань',
#                            'region': 'Татарстан'},
#               'name': 'FOMIN BAR&SHOP',
#               'rating': 8.5},
#              {'location': {'address': 'Победы Пр., 69',
#                            'country': 'RU',
#                            'cross_street': '',
#                            'formatted_address': 'Победы Пр., 69, Казань',
#                            'locality': 'Казань',
#                            'region': 'Республика Татарстан'},
#               'name': 'Горкинско-Ометьевский лес',
#               'rating': 8.8},
#              {'location': {'country': 'RU',
#                            'cross_street': 'Кремлёвская ул.',
#                            'formatted_address': 'Кремлёвская ул., Казань',
#                            'locality': 'Казань',
#                            'region': 'Татарстан'},
#               'name': 'Спасская башня',
#               'rating': 9.1},
#              {'location': {'address': 'Профсоюзная, 22',
#                            'country': 'RU',
#                            'cross_street': '',
#                            'formatted_address': 'Профсоюзная, 22, 420111, '
#                                                 'Казань',
#                            'locality': 'Казань',
#                            'postcode': '420111',
#                            'region': 'Татарстан'},
#               'name': 'Бар Соль',
#               'rating': 8.2},
#              {'location': {'country': 'RU',
#                            'cross_street': '',
#                            'formatted_address': '420014, Казань',
#                            'locality': 'Казань',
#                            'postcode': '420014',
#                            'region': 'Татарстан'},
#               'name': 'Kazan Kremlin (Казанский Кремль)',
#               'rating': 9.3},
#              {'location': {'address': 'Баумана Ул., д. 36',
#                            'country': 'RU',
#                            'cross_street': 'ул. Чернышевского',
#                            'formatted_address': 'Баумана Ул., д. 36 (ул. '
#                                                 'Чернышевского), Казань',
#                            'locality': 'Казань',
#                            'region': 'Татарстан'},
#               'name': 'Top Hop',
#               'rating': 8.4},
#              {'location': {'address': 'Чернышевского 9',
#                            'country': 'RU',
#                            'cross_street': 'Чернышевского-Профсоюзная',
#                            'formatted_address': 'Чернышевского 9 '
#                                                 '(Чернышевского-Профсоюзная), '
#                                                 'Казань',
#                            'locality': 'Казань',
#                            'region': 'Татарстан'},
#               'name': 'Квест-пространство ПАРАНОЙЯ',
#               'rating': 8.4},
#              {'location': {'address': 'Чернышевского Ул., д. 27а',
#                            'address_extended': '27а-цокольный эт.',
#                            'country': 'RU',
#                            'cross_street': '',
#                            'formatted_address': 'Чернышевского Ул., д. 27а, '
#                                                 '420111, Казань',
#                            'locality': 'Казань',
#                            'postcode': '420111',
#                            'region': 'Татарстан'},
#               'name': 'Приют холостяка',
#               'rating': 8.1},
#              {'location': {'country': 'RU',
#                            'cross_street': '',
#                            'formatted_address': 'Казань',
#                            'locality': 'Казань',
#                            'region': 'Татарстан'},
#               'name': 'Смотровая площадка в Казанском Кремле',
#               'rating': 9.1},
#              {'location': {'address': 'Дзержинского Ул., д. 13',
#                            'address_extended': 'эт. 1',
#                            'country': 'RU',
#                            'cross_street': '',
#                            'formatted_address': 'Дзержинского Ул., д. 13, '
#                                                 '420101, Казань',
#                            'locality': 'Казань',
#                            'postcode': '420101',
#                            'region': 'Татарстан'},
#               'name': 'Утка в котелке',
#               'rating': 8.3},
#              {'location': {'country': 'RU',
#                            'cross_street': 'Кремлёвская наб.',
#                            'formatted_address': 'Кремлёвская наб., Казань',
#                            'locality': 'Казань',
#                            'region': 'Татарстан'},
#               'name': 'Автостоянка Кремлевская набережная',
#               'rating': 9.1},
#              {'location': {'country': 'RU',
#                            'cross_street': 'ул. Ершова, 5',
#                            'formatted_address': 'ул. Ершова, 5, Казань',
#                            'locality': 'Казань',
#                            'region': 'Татарстан'},
#               'name': 'Лето',
#               'rating': 8.3},
#              {'location': {'address': 'территория Кремль, 17',
#                            'country': 'RU',
#                            'formatted_address': 'территория Кремль, 17, Казань',
#                            'locality': 'Казань',
#                            'region': 'Татарстан'},
#               'name': 'Башня Сююмбике',
#               'rating': 8.6},
#              {'location': {'address': 'футбольный стадион на зрителей, '
#                                       'расположенный на Ул., д. 45000',
#                            'country': 'RU',
#                            'cross_street': 'Чистопольская ул.',
#                            'formatted_address': 'футбольный стадион на '
#                                                 'зрителей, расположенный на '
#                                                 'Ул., д. 45000 (Чистопольская '
#                                                 'ул.), 421001, Казань',
#                            'locality': 'Казань',
#                            'postcode': '421001',
#                            'region': 'Татарстан'},
#               'name': 'Kazan Arena (Ак Барс Арена)',
#               'rating': 8.3},
#              {'location': {'country': 'RU',
#                            'cross_street': '',
#                            'formatted_address': 'Казань',
#                            'locality': 'Казань',
#                            'region': 'Татарстан'},
#               'name': 'Официальный дилер Mercedes-Benz МБ-Ирбис',
#               'rating': 8.6},
#              {'location': {'address': 'пер. Дуслык Ул., д. 8',
#                            'country': 'RU',
#                            'cross_street': '',
#                            'formatted_address': 'пер. Дуслык Ул., д. 8, Казань',
#                            'locality': 'Казань',
#                            'region': 'Татарстан'},
#               'name': 'Брассерия',
#               'rating': 7.9},
#              {'location': {'address': 'Ямашева Пр., д. 115 А',
#                            'country': 'RU',
#                            'cross_street': '',
#                            'formatted_address': 'Ямашева Пр., д. 115 А, Казань',
#                            'locality': 'Казань',
#                            'region': 'Татарстан'},
#               'name': 'Кидспейс Kidspace',
#               'rating': 8.1},
#              {'location': {'address': 'Ибрагимова 56а',
#                            'country': 'RU',
#                            'cross_street': '',
#                            'formatted_address': 'Ибрагимова 56а, 420000, '
#                                                 'Казань',
#                            'locality': 'Казань',
#                            'postcode': '420000',
#                            'region': 'Татарстан'},
#               'name': 'Панорамный ресторан Van Gogh - Цены на услуги',
#               'rating': 8.2},
#              {'location': {'address': 'Декабристов, 85Б',
#                            'address_extended': 'к1',
#                            'country': 'RU',
#                            'cross_street': '',
#                            'formatted_address': 'Декабристов, 85Б, Казань',
#                            'locality': 'Казань',
#                            'region': 'Татарстан'},
#               'name': 'Нефть',
#               'rating': 8.1},
#              {'location': {'address': 'Адоратского, 12',
#                            'address_extended': 'корп. 2',
#                            'country': 'RU',
#                            'cross_street': '',
#                            'formatted_address': 'Адоратского, 12, Казань',
#                            'locality': 'Казань',
#                            'region': 'Татарстан'},
#               'name': 'Хачапурная',
#               'rating': 8.5},
#              {'location': {'address': 'Декабристов 100',
#                            'country': 'RU',
#                            'cross_street': 'Ямашева-Декабристов',
#                            'formatted_address': 'Декабристов 100 '
#                                                 '(Ямашева-Декабристов), Казань',
#                            'locality': 'Казань',
#                            'region': 'Татарстан'},
#               'name': 'Варка крафтпаб',
#               'rating': 8.3},
#              {'location': {'country': 'RU',
#                            'cross_street': '',
#                            'formatted_address': '420032, Казань',
#                            'locality': 'Казань',
#                            'postcode': '420032',
#                            'region': 'Татарстан'},
#               'name': 'EUROSPAR',
#               'rating': 7.9},
#              {'location': {'address': 'Мамадышский тракт, 46',
#                            'country': 'RU',
#                            'cross_street': '',
#                            'formatted_address': 'Мамадышский тракт, 46, Казань',
#                            'locality': 'Казань',
#                            'region': 'Татарстан'},
#               'name': 'Бахетле',
#               'rating': 8.1},
#              {'location': {'country': 'RU',
#                            'cross_street': '',
#                            'formatted_address': 'Казань',
#                            'locality': 'Казань',
#                            'region': 'Татарстан'},
#               'name': 'Синема 5',
#               'rating': 8.0},
#              {'location': {'country': 'RU',
#                            'cross_street': 'Хусаина Ямашева просп.',
#                            'formatted_address': 'Хусаина Ямашева просп., '
#                                                 'Казань',
#                            'locality': 'Казань',
#                            'region': 'Татарстан'},
#               'name': 'Park Pobedy (Парк Победы)',
#               'rating': 8.0},
#              {'location': {'address': 'Восстания, 8',
#                            'country': 'RU',
#                            'cross_street': '',
#                            'formatted_address': 'Восстания, 8, Казань',
#                            'locality': 'Казань',
#                            'region': 'Татарстан'},
#               'name': 'Покровские пекарни',
#               'rating': 8.0},
#              {'location': {'address': 'Ибрагимова Пр., 39',
#                            'country': 'RU',
#                            'cross_street': '',
#                            'formatted_address': 'Ибрагимова Пр., 39, Казань',
#                            'locality': 'Казань',
#                            'region': 'Татарстан'},
#               'name': 'Дари',
#               'rating': 7.8},
#              {'location': {'address': 'Право-Булачная Ул., д. 5',
#                            'country': 'RU',
#                            'cross_street': 'ул. Баумана, 20',
#                            'formatted_address': 'Право-Булачная Ул., д. 5 (ул. '
#                                                 'Баумана, 20), 420111, Казань',
#                            'locality': 'Казань',
#                            'postcode': '420111',
#                            'region': 'Татарстан'},
#               'name': 'Управление государственных закупок ртl'},
#              {'location': {'country': 'RU',
#                            'cross_street': '',
#                            'formatted_address': 'Казань',
#                            'locality': 'Казань',
#                            'region': 'Татарстан'},
#               'name': 'Березовая роща',
#               'rating': 8.5},
#              {'location': {'address': 'Копылова Ул., д. 2',
#                            'address_extended': 'корп. 1',
#                            'country': 'RU',
#                            'cross_street': '',
#                            'formatted_address': 'Копылова Ул., д. 2, 420036, '
#                                                 'Казань',
#                            'locality': 'Казань',
#                            'postcode': '420036',
#                            'region': 'Татарстан'},
#               'name': 'Рубин, футбольный клуб',
#               'rating': 7.6},
#              {'location': {'address': 'Амирхана Ул., д. 28А.',
#                            'country': 'RU',
#                            'cross_street': '',
#                            'formatted_address': 'Амирхана Ул., д. 28А., '
#                                                 '420132, Казань',
#                            'locality': 'Казань',
#                            'postcode': '420132',
#                            'region': 'Татарстан'},
#               'name': '№132 Школа',
#               'rating': 6.8},
#              {'location': {'address': 'Копылова Ул., д. 2а',
#                            'country': 'RU',
#                            'cross_street': 'ДК Ленина',
#                            'formatted_address': 'Копылова Ул., д. 2а (ДК '
#                                                 'Ленина), Казань',
#                            'locality': 'Казань',
#                            'region': 'Республика Татарстан'},
#               'name': 'Зиланткон, международный конвент',
#               'rating': 7.4},
#              {'location': {'address': 'Голубятникова, 21А',
#                            'country': 'RU',
#                            'cross_street': '',
#                            'formatted_address': 'Голубятникова, 21А, 420094, '
#                                                 'Казань',
#                            'locality': 'Казань',
#                            'postcode': '420094',
#                            'region': 'Республика Татарстан'},
#               'name': 'Эдельвейс',
#               'rating': 6.7},
#              {'location': {'country': 'RU',
#                            'cross_street': 'ул. Мира',
#                            'formatted_address': 'ул. Мира, Казань',
#                            'locality': 'Казань',
#                            'region': 'Татарстан'},
#               'name': 'Детский игровой парк',
#               'rating': 8.1},
#              {'location': {'address': 'Академика Павлова, д.1',
#                            'country': 'RU',
#                            'cross_street': '',
#                            'formatted_address': 'Академика Павлова, д.1, '
#                                                 '420003, Казань',
#                            'locality': 'Казань',
#                            'postcode': '420003',
#                            'region': 'Татарстан'},
#               'name': 'Гостиница Авиатор',
#               'rating': 7.4},
#              {'location': {'address': 'Максимова, 27а',
#                            'address_extended': '1 эт.',
#                            'country': 'RU',
#                            'formatted_address': 'Максимова, 27а, 420127, '
#                                                 'Казань',
#                            'locality': 'Казань',
#                            'postcode': '420127',
#                            'region': 'Татарстан'},
#               'name': 'Хария',
#               'rating': 7.4},
#              {'location': {'address': 'Автодром, 1',
#                            'country': 'RU',
#                            'cross_street': '',
#                            'formatted_address': 'Автодром, 1, Казань',
#                            'locality': 'Казань',
#                            'region': 'Татарстан'},
#               'name': 'KazanRing Canyon (КазанРинг Каньон)',
#               'rating': 8.2},
#              {'location': {'address': 'Горьковское ш., 100',
#                            'country': 'RU',
#                            'cross_street': '',
#                            'formatted_address': 'Горьковское ш., 100, Казань',
#                            'locality': 'Казань',
#                            'region': 'Татарстан'},
#               'name': 'Пламя',
#               'rating': 7.9},
#              {'location': {'address': 'Стадионная Ул., д. 1а',
#                            'address_extended': 'корп. а3 эт.',
#                            'country': 'RU',
#                            'cross_street': 'ул. Тополевая',
#                            'formatted_address': 'Стадионная Ул., д. 1а (ул. '
#                                                 'Тополевая), 420075, Казань',
#                            'locality': 'Казань',
#                            'postcode': '420075',
#                            'region': 'Татарстан'},
#               'name': 'Ракета',
#               'rating': 7.2},
#              {'location': {'address': 'район Приокский, Октябрьская Ул., д. 16',
#                            'country': 'RU',
#                            'cross_street': '',
#                            'formatted_address': 'район Приокский, Октябрьская '
#                                                 'Ул., д. 16',
#                            'region': 'Рязанская область'},
#               'name': 'Ветеран труда',
#               'rating': 6.8},
#              {'location': {'country': 'RU', 'formatted_address': ''},
#               'name': 'Светлая Поляна',
#               'rating': 8.6},
#              {'location': {'address': 'Садовая 106',
#                            'country': 'RU',
#                            'cross_street': '',
#                            'formatted_address': 'Садовая 106',
#                            'region': 'Республика Татарстан'},
#               'name': 'Lounge bar Voda',
#               'rating': 7.3}]}

# %%
establishments = []
for place in data['results']:
    place_name = place.get('name')
    place_address = place.get('location')['formatted_address']
    place_rating = place.get('rating') if 'rating' in place else "Рейтинг не определялся"
    establishments.append({'name': place_name, 'address': place_address, 'rating': place_rating})

# %%
for establishment in establishments:
        print(f"Название: {establishment['name']}")
        print(f"Адрес: {establishment['address']}")
        print(f"Рейтинг: {establishment['rating']}")
        print()
# Out:
# Название: Контора 57
# Адрес: островского 57, Казань
# Рейтинг: 8.9
#
# Название: Золотое яблоко
# Адрес: Декабристов Ул., д. 1, 420107, Казань
# Рейтинг: 8.9
#
# Название: Музей социалистического быта
# Адрес: Университетская Ул., д. 6 (Университетская ул., 6), 420111, Казань
# Рейтинг: 8.9
#
# Название: Галерея Славы Зайцева
# Адрес: Петербургская, 9, 420107, Казань
# Рейтинг: 9.1
#
# Название: АВА-Казань
# Адрес: Астрономическая/Профсоюзная Ул., д.15/19, 420111, Казань
# Рейтинг: 8.8
#
# Название: Петропавловский собор
# Адрес: Мусы Джалиля Ул., д. 21 (ул. Рахматуллина), 420111, Казань
# Рейтинг: 9.3
#
# Название: ЦПКиО им. Горького
# Адрес: Казань
# Рейтинг: 9.2
#
# Название: Штофъ
# Адрес: Ул. Баумана, 9, 420000, Казань
# Рейтинг: 8.8
#
# Название: FOMIN BAR&SHOP
# Адрес: Профсоюзная Ул., д. 10/14, Казань
# Рейтинг: 8.5
#
# Название: Горкинско-Ометьевский лес
# Адрес: Победы Пр., 69, Казань
# Рейтинг: 8.8
#
# Название: Спасская башня
# Адрес: Кремлёвская ул., Казань
# Рейтинг: 9.1
#
# Название: Бар Соль
# Адрес: Профсоюзная, 22, 420111, Казань
# Рейтинг: 8.2
#
# Название: Kazan Kremlin (Казанский Кремль)
# Адрес: 420014, Казань
# Рейтинг: 9.3
#
# Название: Top Hop
# Адрес: Баумана Ул., д. 36 (ул. Чернышевского), Казань
# Рейтинг: 8.4
#
# Название: Квест-пространство ПАРАНОЙЯ
# Адрес: Чернышевского 9 (Чернышевского-Профсоюзная), Казань
# Рейтинг: 8.4
#
# Название: Приют холостяка
# Адрес: Чернышевского Ул., д. 27а, 420111, Казань
# Рейтинг: 8.1
#
# Название: Смотровая площадка в Казанском Кремле
# Адрес: Казань
# Рейтинг: 9.1
#
# Название: Утка в котелке
# Адрес: Дзержинского Ул., д. 13, 420101, Казань
# Рейтинг: 8.3
#
# Название: Автостоянка Кремлевская набережная
# Адрес: Кремлёвская наб., Казань
# Рейтинг: 9.1
#
# Название: Лето
# Адрес: ул. Ершова, 5, Казань
# Рейтинг: 8.3
#
# Название: Башня Сююмбике
# Адрес: территория Кремль, 17, Казань
# Рейтинг: 8.6
#
# Название: Kazan Arena (Ак Барс Арена)
# Адрес: футбольный стадион на зрителей, расположенный на Ул., д. 45000 (Чистопольская ул.), 421001, Казань
# Рейтинг: 8.3
#
# Название: Официальный дилер Mercedes-Benz МБ-Ирбис
# Адрес: Казань
# Рейтинг: 8.6
#
# Название: Брассерия
# Адрес: пер. Дуслык Ул., д. 8, Казань
# Рейтинг: 7.9
#
# Название: Кидспейс Kidspace
# Адрес: Ямашева Пр., д. 115 А, Казань
# Рейтинг: 8.1
#
# Название: Панорамный ресторан Van Gogh - Цены на услуги
# Адрес: Ибрагимова 56а, 420000, Казань
# Рейтинг: 8.2
#
# Название: Нефть
# Адрес: Декабристов, 85Б, Казань
# Рейтинг: 8.1
#
# Название: Хачапурная
# Адрес: Адоратского, 12, Казань
# Рейтинг: 8.5
#
# Название: Варка крафтпаб
# Адрес: Декабристов 100 (Ямашева-Декабристов), Казань
# Рейтинг: 8.3
#
# Название: EUROSPAR
# Адрес: 420032, Казань
# Рейтинг: 7.9
#
# Название: Бахетле
# Адрес: Мамадышский тракт, 46, Казань
# Рейтинг: 8.1
#
# Название: Синема 5
# Адрес: Казань
# Рейтинг: 8.0
#
# Название: Park Pobedy (Парк Победы)
# Адрес: Хусаина Ямашева просп., Казань
# Рейтинг: 8.0
#
# Название: Покровские пекарни
# Адрес: Восстания, 8, Казань
# Рейтинг: 8.0
#
# Название: Дари
# Адрес: Ибрагимова Пр., 39, Казань
# Рейтинг: 7.8
#
# Название: Управление государственных закупок ртl
# Адрес: Право-Булачная Ул., д. 5 (ул. Баумана, 20), 420111, Казань
# Рейтинг: Рейтинг не определялся
#
# Название: Березовая роща
# Адрес: Казань
# Рейтинг: 8.5
#
# Название: Рубин, футбольный клуб
# Адрес: Копылова Ул., д. 2, 420036, Казань
# Рейтинг: 7.6
#
# Название: №132 Школа
# Адрес: Амирхана Ул., д. 28А., 420132, Казань
# Рейтинг: 6.8
#
# Название: Зиланткон, международный конвент
# Адрес: Копылова Ул., д. 2а (ДК Ленина), Казань
# Рейтинг: 7.4
#
# Название: Эдельвейс
# Адрес: Голубятникова, 21А, 420094, Казань
# Рейтинг: 6.7
#
# Название: Детский игровой парк
# Адрес: ул. Мира, Казань
# Рейтинг: 8.1
#
# Название: Гостиница Авиатор
# Адрес: Академика Павлова, д.1, 420003, Казань
# Рейтинг: 7.4
#
# Название: Хария
# Адрес: Максимова, 27а, 420127, Казань
# Рейтинг: 7.4
#
# Название: KazanRing Canyon (КазанРинг Каньон)
# Адрес: Автодром, 1, Казань
# Рейтинг: 8.2
#
# Название: Пламя
# Адрес: Горьковское ш., 100, Казань
# Рейтинг: 7.9
#
# Название: Ракета
# Адрес: Стадионная Ул., д. 1а (ул. Тополевая), 420075, Казань
# Рейтинг: 7.2
#
# Название: Ветеран труда
# Адрес: район Приокский, Октябрьская Ул., д. 16
# Рейтинг: 6.8
#
# Название: Светлая Поляна
# Адрес:
# Рейтинг: 8.6
#
# Название: Lounge bar Voda
# Адрес: Садовая 106
# Рейтинг: 7.3
